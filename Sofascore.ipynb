# %%
import pandas as pd
import json
import requests

# %%
scrape_url="https://api.sofascore.com/api/v1/unique-tournament/1900/season/45661/standings/total"
req=requests.get(scrape_url)
json_obj=json.loads(req.content)

# %%
type(json_obj)
# Out:
# dict

# %%
json_obj.keys()
# Out:
# dict_keys(['standings'])

# %%
len(json_obj)
# Out:
# 1

# %%
json_obj["standings"]
# Out:
# [{'tournament': {'name': 'Indian Super League',
#    'slug': 'indian-super-league',
#    'category': {'name': 'India',
#     'slug': 'india',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 352,
#     'flag': 'india',
#     'alpha2': 'IN'},
#    'uniqueTournament': {'name': 'Indian Super League',
#     'slug': 'indian-super-league',
#     'category': {'name': 'India',
#      'slug': 'india',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 352,
#      'flag': 'india',
#      'alpha2': 'IN'},
#     'userCount': 22314,
#     'id': 1900,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 145,
#    'id': 38566},
#   'type': 'total',
#   'name': 'Super League 22/23',
#   'descriptions': [],
#   'rows': [{'team': {'name': 'Hyderabad FC',
#      'slug': 'hyderabad-fc',
#      'shortName': 'Hyderabad',
#      'gender': 'M',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 8075,
# ...

# %%
type(json_obj["standings"])
# Out:
# list

# %%
json_obj["standings"][0]
# Out:
# {'tournament': {'name': 'Indian Super League',
#   'slug': 'indian-super-league',
#   'category': {'name': 'India',
#    'slug': 'india',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 352,
#    'flag': 'india',
#    'alpha2': 'IN'},
#   'uniqueTournament': {'name': 'Indian Super League',
#    'slug': 'indian-super-league',
#    'category': {'name': 'India',
#     'slug': 'india',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 352,
#     'flag': 'india',
#     'alpha2': 'IN'},
#    'userCount': 22314,
#    'id': 1900,
#    'displayInverseHomeAwayTeams': False},
#   'priority': 145,
#   'id': 38566},
#  'type': 'total',
#  'name': 'Super League 22/23',
#  'descriptions': [],
#  'rows': [{'team': {'name': 'Hyderabad FC',
#     'slug': 'hyderabad-fc',
#     'shortName': 'Hyderabad',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 8075,
#     'nameCode': 'HYD',
# ...

# %%
type(json_obj["standings"][0])
# Out:
# dict

# %%
len(json_obj["standings"][0])
# Out:
# 7

# %%
json_obj["standings"][0].keys()
# Out:
# dict_keys(['tournament', 'type', 'name', 'descriptions', 'rows', 'id', 'updatedAtTimestamp'])

# %%
json_obj["standings"][0]["rows"]
# Out:
# [{'team': {'name': 'Hyderabad FC',
#    'slug': 'hyderabad-fc',
#    'shortName': 'Hyderabad',
#    'gender': 'M',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 8075,
#    'nameCode': 'HYD',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 331840,
#    'teamColors': {'primary': '#0f141b',
#     'secondary': '#f8ca1c',
#     'text': '#f8ca1c'}},
#   'descriptions': [],
#   'promotion': {'text': 'Playoffs', 'id': 6},
#   'position': 1,
#   'matches': 12,
#   'wins': 9,
#   'losses': 2,
#   'draws': 1,
#   'scoresFor': 24,
#   'scoresAgainst': 7,
#   'points': 28,
#   'id': 785838},
#  {'team': {'name': 'Mumbai City FC',
#    'slug': 'mumbai-city-fc',
#    'shortName': 'Mumbai City',
#    'gender': 'M',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'userCount': 11647,
#    'nameCode': 'MUM',
#    'national': False,
#    'type': 0,
#    'id': 174600,
#    'teamColors': {'primary': '#0000ff',
# ...

# %%
pd.json_normalize(json_obj["standings"][0]["rows"])
# Out:
#    descriptions  position  matches  wins  losses  draws  scoresFor  \
# 0            []         1       12     9       2      1         24
# 1            []         2       11     8       0      3         32
# 2            []         3       12     7       3      2         17
# 3            []         4       11     7       3      1         19
# 4            []         5       12     6       5      1         20
# 5            []         6       11     6       4      1         15
# 6            []         7       11     4       5      2         21
# 7            []         8       11     4       7      0         13
# 8            []         9       12     3       8      1          8
# 9            []        10       11     1       8      2          8
# 10           []        11       12     1      11      0         10
#
#     scoresAgainst  points      id  ... team.nameCode team.disabled  \
# 0               7      28  785838  ...           HYD         False
# ...

# %%
isl_data_df=pd.json_normalize(json_obj["standings"][0]["rows"])

# %%
from google.colab import files
isl_data_df.to_csv('isl_data.csv')
files.download('isl_data.csv')
